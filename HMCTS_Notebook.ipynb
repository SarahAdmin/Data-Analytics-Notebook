# %%
import pandas as pd
df = pd.read_csv('HMCTS_MI_output_accessible_July_25.csv',encoding='latin-1')

# %%
df.style.background_gradient(cmap='YlGnBu')
# Out:
# <style type="text/css">
# #T_3ab47_row0_col1, #T_3ab47_row1_col12, #T_3ab47_row2_col26, #T_3ab47_row7_col26 {
#   background-color: #57bec1;
#   color: #000000;
# }
# #T_3ab47_row0_col2 {
#   background-color: #52bcc2;
#   color: #000000;
# }
# #T_3ab47_row0_col3, #T_3ab47_row7_col3, #T_3ab47_row12_col53 {
#   background-color: #ecf7b1;
#   color: #000000;
# }
# #T_3ab47_row0_col4, #T_3ab47_row0_col22, #T_3ab47_row1_col20, #T_3ab47_row7_col34 {
#   background-color: #fafdcf;
#   color: #000000;
# }
# ...

# %%
df1 = pd.read_csv('CSV_HMCTS_Management_Inforamtion_Dec23toDec24 (1).csv',encoding='latin-1')

# %%
df1.style.background_gradient(cmap='RdGy')
# Out:
# <style type="text/css">
# #T_bc19b_row0_col1, #T_bc19b_row0_col27, #T_bc19b_row4_col21 {
#   background-color: #f6b191;
#   color: #000000;
# }
# #T_bc19b_row0_col2, #T_bc19b_row7_col43, #T_bc19b_row8_col43 {
#   background-color: #fee8db;
#   color: #000000;
# }
# ...

# %%
df2 = pd.read_csv('CSV_HMCTS_management_information_Nov22toNov23.csv',encoding='latin-1')

# %%
df2.style.background_gradient(cmap='PuOr')
# Out:
# <style type="text/css">
# #T_1b5a2_row0_col1, #T_1b5a2_row2_col12, #T_1b5a2_row8_col1 {
#   background-color: #bcb7d8;
#   color: #000000;
# }
# ...
