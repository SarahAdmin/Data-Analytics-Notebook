# %%
import pandas as pd
df = pd.read_csv('motorcycle_data.csv',encoding='latin-1')

# %%
df.style.background_gradient(cmap='Oranges')
# Out:
# <style type="text/css">
# #T_26fcb_row0_col3 {
#   background-color: #d94801;
#   color: #f1f1f1;
# }
# #T_26fcb_row1_col3 {
#   background-color: #d54601;
#   color: #f1f1f1;
# }
# #T_26fcb_row2_col3 {
#   background-color: #f26d17;
#   color: #f1f1f1;
# }
# #T_26fcb_row3_col3 {
#   background-color: #cd4401;
#   color: #f1f1f1;
# }
# #T_26fcb_row4_col3 {
#   background-color: #db4a02;
#   color: #f1f1f1;
# }
# #T_26fcb_row5_col3 {
#   background-color: #c14002;
#   color: #f1f1f1;
# }
# #T_26fcb_row6_col3, #T_26fcb_row17_col3, #T_26fcb_row74_col3 {
#   background-color: #9c3203;
#   color: #f1f1f1;
# }
# #T_26fcb_row7_col3 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_26fcb_row8_col3 {
#   background-color: #9e3303;
#   color: #f1f1f1;
# }
# #T_26fcb_row9_col3 {
#   background-color: #932f03;
#   color: #f1f1f1;
# }
# #T_26fcb_row10_col3 {
#   background-color: #ab3803;
#   color: #f1f1f1;
# }
# #T_26fcb_row11_col3, #T_26fcb_row75_col3 {
# ...

# %%
df1 = pd.read_csv('motorcycle theory test data.csv',encoding='latin-1')

# %%
female_data = df1[df1['Gender'] == 'Female']

# %%
female_data.style.background_gradient(cmap='PuBu')
# Out:
# <style type="text/css">
# #T_6576e_row0_col5, #T_6576e_row4_col5 {
#   background-color: #045b8e;
#   color: #f1f1f1;
# }
# #T_6576e_row1_col5 {
#   background-color: #034165;
#   color: #f1f1f1;
# }
# #T_6576e_row2_col5 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_6576e_row3_col5 {
#   background-color: #02395a;
#   color: #f1f1f1;
# }
# #T_6576e_row5_col5 {
#   background-color: #3991c1;
#   color: #f1f1f1;
# }
# #T_6576e_row6_col5 {
#   background-color: #4094c3;
#   color: #f1f1f1;
# }
# #T_6576e_row7_col5 {
#   background-color: #96b6d7;
#   color: #000000;
# }
# #T_6576e_row8_col5 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_6576e_row9_col5, #T_6576e_row11_col5 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_6576e_row10_col5 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_6576e_row12_col5 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_6576e_row13_col5 {
#   background-color: #99b8d8;
# ...

# %%
male_data = df1[df1['Gender'] == 'Male']

# %%
male_data.style.background_gradient(cmap='PuBu')
# Out:
# <style type="text/css">
# #T_0aad5_row0_col5 {
#   background-color: #0771b1;
#   color: #f1f1f1;
# }
# #T_0aad5_row1_col5, #T_0aad5_row4_col5 {
#   background-color: #045b8f;
#   color: #f1f1f1;
# }
# #T_0aad5_row2_col5 {
#   background-color: #023f64;
#   color: #f1f1f1;
# }
# #T_0aad5_row3_col5 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_0aad5_row5_col5 {
#   background-color: #80aed2;
#   color: #f1f1f1;
# }
# #T_0aad5_row6_col5 {
#   background-color: #4a98c5;
#   color: #f1f1f1;
# }
# #T_0aad5_row7_col5 {
#   background-color: #83afd3;
#   color: #f1f1f1;
# }
# #T_0aad5_row8_col5 {
#   background-color: #bcc7e1;
#   color: #000000;
# }
# #T_0aad5_row9_col5, #T_0aad5_row10_col5 {
#   background-color: #c9cee4;
#   color: #000000;
# }
# #T_0aad5_row11_col5 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# #T_0aad5_row12_col5 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_0aad5_row13_col5 {
#   background-color: #6da6cd;
# ...

# %%
df2 = pd.read_csv('car theory test data.csv',encoding='latin-1')

# %%
female_data1 = df2[df2['Gender'] == 'Female']

# %%
female_data1.style.background_gradient(cmap='Purples')
# Out:
# <style type="text/css">
# #T_f0e91_row0_col4 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_f0e91_row1_col4 {
#   background-color: #40027e;
#   color: #f1f1f1;
# }
# #T_f0e91_row2_col4 {
#   background-color: #4d1b89;
#   color: #f1f1f1;
# }
# #T_f0e91_row3_col4 {
#   background-color: #54278f;
#   color: #f1f1f1;
# }
# #T_f0e91_row4_col4 {
#   background-color: #65489f;
#   color: #f1f1f1;
# }
# #T_f0e91_row5_col4 {
#   background-color: #705eaa;
#   color: #f1f1f1;
# }
# #T_f0e91_row6_col4 {
#   background-color: #babadb;
#   color: #000000;
# }
# #T_f0e91_row7_col4 {
#   background-color: #c5c6e1;
#   color: #000000;
# }
# #T_f0e91_row8_col4 {
#   background-color: #dedeed;
#   color: #000000;
# }
# #T_f0e91_row9_col4, #T_f0e91_row10_col4 {
#   background-color: #e0e0ee;
#   color: #000000;
# }
# #T_f0e91_row11_col4 {
#   background-color: #ecebf4;
#   color: #000000;
# }
# #T_f0e91_row12_col4 {
#   background-color: #edebf4;
#   color: #000000;
# }
# ...

# %%
male_data1 = df2[df2['Gender'] == 'Male']

# %%
male_data1.style.background_gradient(cmap='Purples')
# Out:
# <style type="text/css">
# #T_14df1_row0_col4 {
#   background-color: #41047f;
#   color: #f1f1f1;
# }
# #T_14df1_row1_col4 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_14df1_row2_col4 {
#   background-color: #4c1788;
#   color: #f1f1f1;
# }
# #T_14df1_row3_col4 {
#   background-color: #51228d;
#   color: #f1f1f1;
# }
# #T_14df1_row4_col4 {
#   background-color: #66499f;
#   color: #f1f1f1;
# }
# #T_14df1_row5_col4 {
#   background-color: #776cb1;
#   color: #f1f1f1;
# }
# #T_14df1_row6_col4 {
#   background-color: #cecfe5;
#   color: #000000;
# }
# #T_14df1_row7_col4 {
#   background-color: #cfd0e6;
#   color: #000000;
# }
# #T_14df1_row8_col4 {
#   background-color: #dbdbec;
#   color: #000000;
# }
# #T_14df1_row9_col4, #T_14df1_row10_col4 {
#   background-color: #e3e2ef;
#   color: #000000;
# }
# #T_14df1_row11_col4 {
#   background-color: #edebf4;
#   color: #000000;
# }
# #T_14df1_row12_col4 {
#   background-color: #efedf5;
#   color: #000000;
# }
# ...
