# %%
import pandas as pd

# %%
df = pd.read_csv('Blood Alcohol data - Sheet1.csv',encoding='latin-1')

# %% [markdown]
# Blood Alcohol results throughout 1979 - 2023 shows the number of drivers and motocycle riders have blood alcohol.

# %%
df = df.style.background_gradient(cmap='Oranges')

# %%
df
# Out:
# <style type="text/css">
# #T_e94f7_row0_col0, #T_e94f7_row1_col0, #T_e94f7_row60_col4, #T_e94f7_row62_col5, #T_e94f7_row66_col3, #T_e94f7_row66_col6, #T_e94f7_row68_col2, #T_e94f7_row74_col2, #T_e94f7_row76_col2, #T_e94f7_row80_col2 {
#   background-color: #fff5eb;
#   color: #000000;
# }
# #T_e94f7_row0_col2, #T_e94f7_row7_col2 {
#   background-color: #a13403;
#   color: #f1f1f1;
# }
# #T_e94f7_row0_col3, #T_e94f7_row1_col3, #T_e94f7_row11_col3, #T_e94f7_row15_col3 {
#   background-color: #9c3203;
#   color: #f1f1f1;
# }
# #T_e94f7_row0_col4 {
#   background-color: #b63c02;
#   color: #f1f1f1;
# }
# #T_e94f7_row0_col5, #T_e94f7_row4_col4, #T_e94f7_row7_col3, #T_e94f7_row7_col6, #T_e94f7_row9_col2, #T_e94f7_row88_col0, #T_e94f7_row89_col0 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_e94f7_row0_col6, #T_e94f7_row2_col3, #T_e94f7_row4_col3 {
#   background-color: #a03403;
#   color: #f1f1f1;
# }
# #T_e94f7_row1_col2, #T_e94f7_row9_col3 {
#   background-color: #973003;
# ...

# %%
df1 = pd.read_csv('screening_breath_test - Sheet1.csv',encoding='latin-1')

# %%
final_df = df1.style.background_gradient(cmap='Oranges')

# %%
final_df
# Out:
# <style type="text/css">
# #T_41482_row0_col0, #T_41482_row1_col0, #T_41482_row2_col0, #T_41482_row3_col0 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_41482_row4_col0, #T_41482_row5_col0, #T_41482_row6_col0, #T_41482_row7_col0 {
#   background-color: #a13403;
#   color: #f1f1f1;
# }
# #T_41482_row8_col0, #T_41482_row9_col0, #T_41482_row10_col0, #T_41482_row11_col0 {
#   background-color: #cd4401;
#   color: #f1f1f1;
# }
# #T_41482_row12_col0, #T_41482_row13_col0, #T_41482_row14_col0, #T_41482_row15_col0 {
#   background-color: #e95e0d;
#   color: #f1f1f1;
# }
# #T_41482_row16_col0, #T_41482_row17_col0, #T_41482_row18_col0, #T_41482_row19_col0 {
#   background-color: #f87d29;
#   color: #f1f1f1;
# }
# #T_41482_row20_col0, #T_41482_row21_col0, #T_41482_row22_col0, #T_41482_row23_col0 {
#   background-color: #fd9c51;
#   color: #000000;
# }
# #T_41482_row24_col0, #T_41482_row25_col0, #T_41482_row26_col0, #T_41482_row27_col0 {
#   background-color: #fdb97d;
# ...
