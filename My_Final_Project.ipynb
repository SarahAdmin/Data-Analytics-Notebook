# %% [markdown]
# <a href="https://colab.research.google.com/github/SarahAdmin/Data-Analytics-Notebook/blob/main/My_Final_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv('dvsa-com-01-summary-of-annual-tests-for-lorries-buses-and-trailers (1).csv',encoding='latin-1')

# %%
print(df.to_string())
# Out:
#              Year                          Period Vehicle type Premise type    Tests Pass after rectification   Fails Initial fail rate Final fail rate Retests Retest fail rate
# 0    2025 to 2026        Quarter 1: April to June          HGV     Non DVSA  113,444                    3,700   8,100            10.40%           7.14%   7,418            6.08%
# 1    2025 to 2026        Quarter 1: April to June          HGV         DVSA      119                        5      13            15.13%          10.92%       7            0.00%
# 2    2025 to 2026        Quarter 1: April to June          HGV     Subtotal  113,563                    3,705   8,113            10.40%           7.14%   7,425            6.08%
# 3    2025 to 2026        Quarter 1: April to June          PSV     Non DVSA   18,430                      510   1,082             8.64%           5.87%     966            5.90%
# ...

# %%
columnsToRemove = ['Initial fail rate', 'Final fail rate','Retest fail rate']

# %%
df1 = df.drop(columnsToRemove, axis=1)

# %%
new_df1 = df1.head(250)

# %%
new_df1
# Out:
#              Year                    Period Vehicle type Premise type  \
# 0    2025 to 2026  Quarter 1: April to June          HGV     Non DVSA
# 1    2025 to 2026  Quarter 1: April to June          HGV         DVSA
# 2    2025 to 2026  Quarter 1: April to June          HGV     Subtotal
# 3    2025 to 2026  Quarter 1: April to June          PSV     Non DVSA
# 4    2025 to 2026  Quarter 1: April to June          PSV         DVSA
# ..            ...                       ...          ...          ...
# 245  2019 to 2020  Quarter 1: April to June          PSV     Subtotal
# 246  2019 to 2020  Quarter 1: April to June      Trailer     Non DVSA
# 247  2019 to 2020  Quarter 1: April to June      Trailer         DVSA
# 248  2019 to 2020  Quarter 1: April to June      Trailer     Subtotal
# 249  2019 to 2020  Quarter 1: April to June        Total        Total
#
#        Tests Pass after rectification   Fails Retests
# 0    113,444                    3,700   8,100   7,418
# ...

# %%
finDF = pd.read_excel('NCCG 2324 accounts workings data (1).xlsx',sheet_name='Check of bank statement')

# %%
print(finDF.dtypes)
# Out:
# Period                  object
# Cash opening           float64
# Receipts               float64
# Payments               float64
# Bank Cash closing      float64
# Check                  float64
# Difference               int64
# Period.1                object
# Cash opening.1         float64
# Receipts.1             float64
# Payments.1               int64
# Bank Cash closing.1    float64
# Check.1                float64
# Difference.1             int64
# dtype: object

# %%
finDF.style.background_gradient(cmap='Oranges')
# Out:
# <style type="text/css">
# #T_616bc_row0_col1 {
#   background-color: #fdbe84;
#   color: #000000;
# }
# #T_616bc_row0_col2 {
#   background-color: #973003;
#   color: #f1f1f1;
# }
# #T_616bc_row0_col3, #T_616bc_row6_col2, #T_616bc_row9_col4, #T_616bc_row9_col5, #T_616bc_row10_col1, #T_616bc_row11_col8, #T_616bc_row11_col9, #T_616bc_row11_col11, #T_616bc_row11_col12 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# ...

# %% [markdown]
# The Bank Statement shows payments and budgets for the client's church has cash openings and closings throughout the year with no differences.
